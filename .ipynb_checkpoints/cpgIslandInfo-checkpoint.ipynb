# %%
f = open("SignificantCpG_var10k_allData",'r')
g = f.read()
cpgSites = g.split("\n")
cpgSites = cpgSites[:-1]
# Out:
# 10000

# %%
import pandas as pd
direc = "C:/Users/chsue/Documents/MITyear3/6.047/GDACLAMLmethyl450/data/"
cpgInfo = pd.read_csv(direc+"HumanMethylation450_15017482_v1-2.csv",skiprows=[0,1,2,3,4,5,6])
importantCpgs = cpgInfo.loc[cpgInfo['IlmnID'].isin(cpgSites)]
# Out:
# C:\Users\chsue\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (2,4,11,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
importantGenes = importantCpgs.dropna(subset=['UCSC_RefGene_Name'])["UCSC_RefGene_Name"] # 7022 of sites are assoc w gene
geneSets = [geneSet.split(";") for geneSet in list(importantGenes)]
importantGenesUniqueList = set()
importantGenesDict = {}
for geneSet in geneSets:
    seen = False
    for gene in geneSet:
        if not seen:
            if gene not in importantGenesDict:
                importantGenesDict[gene] = 0
            importantGenesDict[gene] += 1
            seen = True
        importantGenesUniqueList.add(gene)
importantGenesUniqueList = list(importantGenesUniqueList)  ## ends up being 4846 unique genes...
sorted(importantGenesDict.items(), key=lambda kv: kv[1],reverse=True)
# Out:
# [('PCDHGA4', 51),
#  ('PTPRN2', 24),
#  ('GNAS', 20),
#  ('RPTOR', 16),
#  ('PRDM16', 15),
#  ('HCCA2', 15),
#  ('PCDHA6', 15),
#  ('PCDHA2', 14),
#  ('TNXB', 14),
#  ('PCDHGA2', 12),
#  ('HRNBP3', 12),
#  ('AGAP1', 11),
#  ('SEPT9', 11),
#  ('DIP2C', 11),
#  ('WT1', 10),
#  ('ZIC1', 10),
#  ('BAHCC1', 9),
#  ('HOXA4', 9),
#  ('TP73', 9),
#  ('DPP6', 9),
#  ('PRDM8', 9),
#  ('GNASAS', 8),
#  ('SGCE', 8),
#  ('PLEC1', 8),
#  ('AMT', 8),
#  ('MCF2L', 8),
#  ('C7orf50', 8),
#  ('RNF39', 8),
#  ('CAMTA1', 7),
#  ('C2orf65', 7),
#  ('SBNO2', 7),
#  ('ADARB2', 7),
#  ('ALOX12', 7),
#  ('FLJ12825', 7),
#  ('NKAPL', 7),
#  ('SDK1', 7),
#  ('KIF26B', 7),
#  ('BRUNOL4', 7),
#  ('MEST', 7),
#  ('DGKG', 6),
#  ('IFT140', 6),
#  ('CACNA2D4', 6),
#  ('SAMD11', 6),
#  ('OPCML', 6),
#  ('MIR886', 6),
#  ('SYNGAP1', 6),
#  ('FOXK1', 6),
#  ('HORMAD2', 6),
#  ('LOC404266', 6),
#  ('HDAC4', 6),
#  ('GABBR1', 6),
#  ('SORCS2', 6),
#  ('SHANK2', 6),
#  ('ODZ4', 6),
#  ('VGLL4', 6),
#  ('TBCD', 6),
#  ('MYT1L', 6),
#  ('PRDM13', 6),
#  ('KCNQ1', 6),
#  ('L3MBTL', 6),
#  ('SLC43A2', 6),
#  ('MIB2', 6),
#  ('C22orf45', 6),
#  ('HOXC4', 6),
#  ('RASA3', 6),
#  ('TCERG1L', 5),
#  ('RPS6KA2', 5),
#  ('SORBS2', 5),
#  ('PACS2', 5),
#  ('ZFPM1', 5),
#  ('MEG3', 5),
#  ('SRRM4', 5),
#  ('MAD1L1', 5),
#  ('LOXL1', 5),
#  ('RB1', 5),
#  ('ARHGEF10', 5),
#  ('NCKAP5', 5),
#  ('C1QL4', 5),
#  ('GRM2', 5),
#  ('ANK1', 5),
#  ('TRIM15', 5),
#  ('SEZ6', 5),
#  ('CCDC81', 5),
#  ('KNDC1', 5),
#  ('GREM2', 5),
#  ('TRAK1', 5),
#  ('ANKRD11', 5),
#  ('RUNX3', 5),
#  ('PALM', 5),
#  ('ACSF3', 5),
#  ('SYNPO2L', 5),
#  ('CD164L2', 5),
#  ('KLHL35', 5),
#  ('HKR1', 5),
#  ('HOXA2', 5),
#  ('SEC31B', 5),
#  ('BRSK2', 5),
#  ('RGS12', 5),
#  ('TACSTD2', 5),
#  ('CREB5', 5),
#  ('PCDHB4', 5),
#  ('SIM1', 5),
#  ('MAML3', 5),
#  ('LOC254559', 5),
#  ('DIRAS3', 5),
#  ('SNRPN', 5),
#  ('A2BP1', 5),
#  ('C20orf54', 5),
#  ('RPH3AL', 5),
#  ('DLG2', 5),
#  ('RNU5E', 5),
#  ('CBFA2T3', 5),
#  ('LEP', 5),
#  ('CCDC85C', 5),
#  ('GALNT9', 5),
#  ('HLA-G', 5),
#  ('NAT15', 5),
#  ('JAKMIP1', 5),
#  ('PRHOXNB', 5),
#  ('SLC35F3', 5),
#  ('SKI', 5),
#  ('MACROD1', 5),
#  ('GFPT2', 5),
#  ('IGF2BP1', 5),
#  ('KLHL29', 5),
#  ('ZNF876P', 5),
#  ('BTBD3', 5),
#  ('TMEM79', 5),
#  ('PRKAR1B', 5),
#  ('EPHA10', 5),
#  ('NR4A2', 5),
#  ('TACC2', 5),
#  ('ZIC4', 5),
#  ('PRDM6', 5),
#  ('ANKMY1', 5),
#  ('DLG4', 4),
#  ('LMO3', 4),
#  ('CCDC36', 4),
#  ('MOV10L1', 4),
#  ('HOXD4', 4),
#  ('PDE4C', 4),
#  ('PSKH2', 4),
#  ('CETP', 4),
#  ('GDF7', 4),
#  ('TRERF1', 4),
#  ('ANKRD30B', 4),
#  ('CCDC88C', 4),
#  ('WNT6', 4),
#  ('TFAP2A', 4),
#  ('PDE4D', 4),
#  ('FBRSL1', 4),
#  ('IKZF1', 4),
#  ('DNAH1', 4),
#  ('CDH11', 4),
#  ('PRKCZ', 4),
#  ('PRLHR', 4),
#  ('RAB11FIP1', 4),
#  ('NRIP2', 4),
#  ('PAX7', 4),
#  ('TSNAX-DISC1', 4),
#  ('GATA4', 4),
#  ('LAMA5', 4),
#  ('MGAT5B', 4),
#  ('CARS2', 4),
#  ('C18orf1', 4),
#  ('PCDHA7', 4),
#  ('ARHGEF3', 4),
#  ('PRRT1', 4),
#  ('ZEB2', 4),
#  ('ACCN1', 4),
#  ('RAB11FIP3', 4),
#  ('LOC650226', 4),
#  ('TTBK1', 4),
#  ('RAI1', 4),
#  ('BCL11A', 4),
#  ('SEMA6B', 4),
#  ('ELTD1', 4),
#  ('ADAMTS2', 4),
#  ('SLC9A3', 4),
#  ('NCOR2', 4),
#  ('SCGN', 4),
#  ('IQSEC3', 4),
#  ('PCDHB16', 4),
#  ('LPCAT1', 4),
#  ('IGF1R', 4),
#  ('ADAMTS17', 4),
#  ('RIN2', 4),
#  ('GPSM3', 4),
#  ('COL11A2', 4),
#  ('CYP26C1', 4),
#  ('PTPRE', 4),
#  ('HLA-DPB2', 4),
#  ('MDGA1', 4),
#  ('IQSEC1', 4),
#  ('RCAN3', 4),
#  ('VAX2', 4),
#  ('MARCH1', 4),
#  ('KRT72', 4),
#  ('HLA-DMB', 4),
#  ('SLC11A1', 4),
#  ('PF4V1', 4),
#  ('TRAF3', 4),
#  ('NXPH1', 4),
#  ('CA5A', 4),
#  ('LOC145845', 4),
#  ('ZADH2', 4),
#  ('EPB49', 4),
#  ('B3GNTL1', 4),
#  ('CAPG', 4),
#  ('PCDHB7', 4),
#  ('DRD4', 4),
#  ('PCDHB6', 4),
#  ('SLC43A1', 4),
#  ('GAS7', 4),
#  ('FAM71D', 4),
#  ('PRKAG2', 4),
#  ('IGSF21', 4),
#  ('MTNR1B', 4),
#  ('SNTG2', 4),
#  ('TNS3', 4),
#  ('FUT4', 4),
#  ('MACF1', 4),
#  ('DDR1', 4),
#  ('FILIP1', 4),
#  ('MRGPRF', 4),
#  ('BCL11B', 4),
#  ('TSPAN4', 4),
#  ('STAT3', 4),
#  ('NRXN1', 4),
#  ('KDM2B', 4),
#  ('TBC1D14', 4),
#  ('COL23A1', 4),
#  ('PLAGL1', 4),
#  ('AMPD3', 4),
#  ('NXN', 4),
#  ('ATP11A', 4),
#  ('IFFO1', 4),
#  ('C1orf159', 4),
#  ('STK32C', 4),
#  ('PAX6', 4),
#  ('GPR6', 4),
#  ('MYH14', 3),
#  ('ESRRG', 3),
#  ('MFSD2B', 3),
#  ('SLC6A5', 3),
#  ('C17orf64', 3),
#  ('ACTN3', 3),
#  ('JPH2', 3),
#  ('POLR3GL', 3),
#  ('SERINC5', 3),
#  ('ZBTB22', 3),
#  ('TMEM132D', 3),
#  ('NGFR', 3),
#  ('CACNB2', 3),
#  ('PRKCA', 3),
#  ('ERGIC1', 3),
#  ('C3orf21', 3),
#  ('ZNF385A', 3),
#  ('CHST4', 3),
#  ('C20orf166', 3),
#  ('NDRG2', 3),
#  ('PM20D1', 3),
#  ('EPHA8', 3),
#  ('CHD5', 3),
#  ('STAG3', 3),
#  ('HOPX', 3),
#  ('SLC9A9', 3),
#  ('SYNPO', 3),
#  ('C1orf86', 3),
#  ('MANEAL', 3),
#  ('SERPINE1', 3),
#  ('ZDHHC14', 3),
#  ('ADO', 3),
#  ('OSBPL5', 3),
#  ('C8orf73', 3),
#  ('USP10', 3),
#  ('UNC13D', 3),
#  ('SHANK1', 3),
#  ('OTP', 3),
#  ('SPRED2', 3),
#  ('LOC134466', 3),
#  ('C20orf26', 3),
#  ('NOTCH4', 3),
#  ('C15orf27', 3),
#  ('CACNA1B', 3),
#  ('TESC', 3),
#  ('LPAR5', 3),
#  ('PDE2A', 3),
#  ('CHD3', 3),
#  ('RNF212', 3),
#  ('PEG3', 3),
#  ('NFIL3', 3),
#  ('CILP2', 3),
#  ('GRIN2D', 3),
#  ('SYCN', 3),
#  ('MYLK', 3),
#  ('TFAP2E', 3),
#  ('PCDHA1', 3),
#  ('FCHO1', 3),
#  ('EBF3', 3),
#  ('MLXIPL', 3),
#  ('ECE2', 3),
#  ('SGK1', 3),
#  ('GALK2', 3),
#  ('ILDR2', 3),
#  ('POU2AF1', 3),
#  ('SSTR1', 3),
#  ('SLC25A42', 3),
#  ('CERK', 3),
#  ('MICB', 3),
#  ('TMC8', 3),
#  ('SLC7A14', 3),
#  ('RSPH10B', 3),
#  ('CYB561', 3),
#  ('SLC8A2', 3),
#  ('GDNF', 3),
#  ('ALS2CR11', 3),
#  ('KCNQ1DN', 3),
#  ('ZBTB7B', 3),
#  ('RUSC1', 3),
#  ('RCVRN', 3),
#  ('C3orf55', 3),
#  ('EVX1', 3),
#  ('C1orf228', 3),
#  ('CUX1', 3),
#  ('FOXN3', 3),
#  ('CYP1A1', 3),
#  ('SH3TC1', 3),
#  ('KCNE1', 3),
#  ('PPP2R2C', 3),
#  ('EZR', 3),
#  ('IGF2BP2', 3),
#  ('FEZF2', 3),
#  ('ELANE', 3),
#  ('ZPBP2', 3),
#  ('KCNQ1OT1', 3),
#  ('XPNPEP1', 3),
#  ('FBXO34', 3),
#  ('DUSP5', 3),
#  ('GATA2', 3),
#  ('LSP1', 3),
#  ('FAM53B', 3),
#  ('GRIN1', 3),
#  ('H19', 3),
#  ('DCC', 3),
#  ('CRISPLD2', 3),
#  ('SLC17A8', 3),
#  ('SPTBN4', 3),
#  ('CACNB4', 3),
#  ('CACNA1H', 3),
#  ('OBSCN', 3),
#  ('LOC440839', 3),
#  ('LIME1', 3),
#  ('ZFR2', 3),
#  ('GRID1', 3),
#  ('PNMAL2', 3),
#  ('DHX16', 3),
#  ('AUTS2', 3),
#  ('THADA', 3),
#  ('TCF7L2', 3),
#  ('KBTBD11', 3),
#  ('NCAM1', 3),
#  ('FGF2', 3),
#  ('BTG2', 3),
#  ('SLC6A11', 3),
#  ('CRB2', 3),
#  ('MSX1', 3),
#  ('LAMA2', 3),
#  ('PIP4K2A', 3),
#  ('RBPJL', 3),
#  ('NAV2', 3),
#  ('ZC3H12D', 3),
#  ('GSTM5', 3),
#  ('NFIC', 3),
#  ('SCG5', 3),
#  ('KLHL25', 3),
#  ('ZNF331', 3),
#  ('ZSCAN12L1', 3),
#  ('C6orf27', 3),
#  ('TIMP2', 3),
#  ('BCL2', 3),
#  ('RAD52', 3),
#  ('WDR52', 3),
#  ('NOTCH1', 3),
#  ('B3GALT4', 3),
#  ('CSNK1E', 3),
#  ('S100A8', 3),
#  ('HLCS', 3),
#  ('MIR1207', 3),
#  ('HIVEP3', 3),
#  ('DSCAML1', 3),
#  ('ARHGEF10L', 3),
#  ('SLC44A4', 3),
#  ('BIK', 3),
#  ('CNTN1', 3),
#  ('TTYH1', 3),
#  ('LOC100130274', 3),
#  ('ICAM5', 3),
#  ('GRB10', 3),
#  ('CACNA1C', 3),
#  ('TRIM10', 3),
#  ('TIAM2', 3),
#  ('NFIX', 3),
#  ('PIK3CD', 3),
#  ('SOSTDC1', 3),
#  ('KIAA0513', 3),
#  ('PRDM2', 3),
#  ('USP7', 3),
#  ('CABLES1', 3),
#  ('XRCC3', 3),
#  ('TCF21', 3),
#  ('DDAH2', 3),
#  ('DAB1', 3),
#  ('DNASE1L2', 3),
#  ('PLAC2', 3),
#  ('TRIM4', 3),
#  ('OXT', 3),
#  ('SYT7', 3),
#  ('CHL1', 3),
#  ('F2RL1', 3),
#  ('CNFN', 3),
#  ('HLA-DQB2', 3),
#  ('TNNC2', 3),
#  ('LZTS2', 3),
#  ('DLEU7', 3),
#  ('LFNG', 3),
#  ('C11orf93', 3),
#  ('ZSCAN1', 3),
#  ('ALDH1A3', 3),
#  ('MGRN1', 3),
#  ('TCF7', 3),
#  ('PHOSPHO1', 3),
#  ('RAB3B', 3),
#  ('SSBP3', 3),
#  ('NRP2', 3),
#  ('HRK', 3),
#  ('NTN1', 3),
#  ('ARL5C', 3),
#  ('MSI2', 3),
#  ('SRPK2', 3),
#  ('ENTPD1', 3),
#  ('CHRNE', 3),
#  ('MAML2', 3),
#  ('CACNG6', 3),
#  ('ABAT', 3),
#  ('KIAA1949', 3),
#  ('METRNL', 3),
#  ('DTNB', 3),
#  ('SEC14L4', 3),
#  ('NLRP3', 3),
#  ('ADAP1', 3),
#  ('FOXP1', 3),
#  ('F10', 3),
#  ('SNED1', 3),
#  ('DLX6AS', 3),
#  ('OLFM3', 3),
#  ('PRAP1', 3),
#  ('PKLR', 3),
#  ('MPO', 3),
#  ('FAM123C', 3),
#  ('MARCH8', 3),
#  ('TBR1', 3),
#  ('ATP8A2', 3),
#  ('GPR56', 3),
#  ('CXCR5', 3),
#  ('MAMSTR', 3),
#  ('CALR', 3),
#  ('RSPH9', 3),
#  ('ITGAE', 3),
#  ('TBX3', 3),
#  ('LRP5', 3),
#  ('OPA3', 3),
#  ('RXRA', 3),
#  ('NRG1', 3),
#  ('CDC42BPB', 3),
#  ('LTK', 3),
#  ('PLXNB2', 3),
#  ('PCDHB17', 3),
#  ('PCDHB11', 3),
#  ('NOXO1', 3),
#  ('VAV2', 3),
#  ('RAD51L1', 3),
#  ('IZUMO1', 3),
#  ('OTX2', 3),
#  ('EVPL', 3),
#  ('WIT1', 3),
#  ('ASCL2', 3),
#  ('ANKS1B', 3),
#  ('RORA', 3),
#  ('SLC5A10', 3),
#  ('MESP2', 3),
#  ('ST5', 3),
#  ('LHX3', 3),
#  ('SH3BP2', 3),
#  ('PNPLA2', 3),
#  ('KLB', 3),
#  ('NARFL', 3),
#  ('HYAL2', 2),
#  ('FANCC', 2),
#  ('MYF5', 2),
#  ('ELMO1', 2),
#  ('SPTBN1', 2),
#  ('COL4A2', 2),
#  ('NELL2', 2),
#  ('RELT', 2),
#  ('SFTA2', 2),
#  ('TRABD', 2),
#  ('C8orf44', 2),
#  ('TERC', 2),
#  ('GJD4', 2),
#  ('SST', 2),
#  ('GABRA5', 2),
#  ('ITPK1', 2),
#  ('TPST1', 2),
#  ('EDARADD', 2),
#  ('NFATC2', 2),
#  ('RAPGEF2', 2),
#  ('FLT4', 2),
#  ('HSPA4L', 2),
#  ('CCDC46', 2),
#  ('SFRP2', 2),
#  ('DSCR6', 2),
#  ('TAPBP', 2),
#  ('LOC729991-MEF2B', 2),
#  ('CA10', 2),
#  ('ZNF205', 2),
#  ('FBXO17', 2),
#  ('ARSJ', 2),
#  ('LOC144571', 2),
#  ('ADAM32', 2),
#  ('HK1', 2),
#  ('RPH3A', 2),
#  ('C2CD4A', 2),
#  ('KLHL2', 2),
#  ('TRAPPC9', 2),
#  ('SLC38A11', 2),
#  ('DMKN', 2),
#  ('CLDN9', 2),
#  ('TEKT4', 2),
#  ('LOC146880', 2),
#  ('AMN', 2),
#  ('CCNT1', 2),
#  ('C1orf38', 2),
#  ('ATAD3C', 2),
#  ('DDX47', 2),
#  ('NBLA00301', 2),
#  ('OSR1', 2),
#  ('ANKRD20B', 2),
#  ('DTX4', 2),
#  ('SFMBT2', 2),
#  ('ZNF783', 2),
#  ('RTBDN', 2),
#  ('GRRP1', 2),
#  ('C8ORFK29', 2),
#  ('NKX2-6', 2),
#  ('DGKA', 2),
#  ('PCDHB14', 2),
#  ('ZNF560', 2),
#  ('KRT18', 2),
#  ('FAM164C', 2),
#  ('GRIK3', 2),
#  ('SMOC2', 2),
#  ('TSKS', 2),
#  ('ALOX5', 2),
#  ('GPR62', 2),
#  ('TMEM190', 2),
#  ('ETS1', 2),
#  ('CTNNA3', 2),
#  ('UNC5D', 2),
#  ('ZSCAN18', 2),
#  ('BHMT', 2),
#  ('SOCS1', 2),
#  ('EBF4', 2),
#  ('FAM96B', 2),
#  ('UCN', 2),
#  ('C17orf96', 2),
#  ('INCA1', 2),
#  ('LAMB2', 2),
#  ('ALPK3', 2),
#  ('PIP5K1C', 2),
#  ('ZFYVE28', 2),
#  ('EPHA4', 2),
#  ('CYFIP2', 2),
#  ('PGAM2', 2),
#  ('FBLL1', 2),
#  ('DOCK6', 2),
#  ('HSPB6', 2),
#  ('COL11A1', 2),
#  ('IFNGR2', 2),
#  ('ALDH3A1', 2),
#  ('CCDC149', 2),
#  ('ESR1', 2),
#  ('ABLIM2', 2),
#  ('PCMTD1', 2),
#  ('PLEK2', 2),
#  ('PVT1', 2),
#  ('PTCH1', 2),
#  ('STAT5A', 2),
#  ('CYP7B1', 2),
#  ('VSTM2A', 2),
#  ('PI16', 2),
#  ('PTGDS', 2),
#  ('PACRG', 2),
#  ('LITAF', 2),
#  ('SRP9', 2),
#  ('CALD1', 2),
#  ('RGMA', 2),
#  ('SOX18', 2),
#  ('FBXO31', 2),
#  ('XKR6', 2),
#  ('D4S234E', 2),
#  ('GNG7', 2),
#  ('EIF4E3', 2),
#  ('PRAME', 2),
#  ('FLJ40504', 2),
#  ('RALYL', 2),
#  ('MOCS1', 2),
#  ('PCGF3', 2),
#  ('EVX2', 2),
#  ('DSP', 2),
#  ('CRTAC1', 2),
#  ('SLC6A18', 2),
#  ('NTRK1', 2),
#  ('KCNA3', 2),
#  ('TP53INP1', 2),
#  ('TTLL10', 2),
#  ('SLC10A1', 2),
#  ('RPS2P32', 2),
#  ('IFITM1', 2),
#  ('MRPL16', 2),
#  ('PTK2B', 2),
#  ('TMEM30B', 2),
#  ('CEBPE', 2),
#  ('SOX11', 2),
#  ('GPR144', 2),
#  ('NADK', 2),
#  ('TNR', 2),
#  ('ZNF721', 2),
#  ('HNRNPF', 2),
#  ('PCDHGB4', 2),
#  ('PITPNC1', 2),
#  ('PFKFB3', 2),
#  ('CALCA', 2),
#  ('HIST2H2BF', 2),
#  ('DKK4', 2),
#  ('CREB3L1', 2),
#  ('FGF17', 2),
#  ('SLC20A1', 2),
#  ('RASGEF1A', 2),
#  ('FGD5', 2),
#  ('TTYH3', 2),
#  ('SCARA3', 2),
#  ('SPNS1', 2),
#  ('CATSPER4', 2),
#  ('PRKG1', 2),
#  ('SLC9A2', 2),
#  ('C16orf11', 2),
#  ('NOS2', 2),
#  ('TRIM2', 2),
#  ('CPEB1', 2),
#  ('IL5RA', 2),
#  ('SDCCAG8', 2),
#  ('BRCA2', 2),
#  ('ZBTB16', 2),
#  ('SCUBE1', 2),
#  ('SH3PXD2B', 2),
#  ('TRIM26', 2),
#  ('PTPRK', 2),
#  ('SLC9A10', 2),
#  ('LY6G6E', 2),
#  ('ZNF232', 2),
#  ('STAMBPL1', 2),
#  ('NCR1', 2),
#  ('XKR4', 2),
#  ('KCNS2', 2),
#  ('PCDHB9', 2),
#  ('PTGS2', 2),
#  ('BTBD17', 2),
#  ('KLF6', 2),
#  ('BNC1', 2),
#  ('CNDP2', 2),
#  ('PSTPIP2', 2),
#  ('NAP1L5', 2),
#  ('ACTA2', 2),
#  ('TFCP2L1', 2),
#  ('TBX15', 2),
#  ('CYTSB', 2),
#  ('KIAA0319L', 2),
#  ('SCHIP1', 2),
#  ('CLCNKB', 2),
#  ('SH2D4B', 2),
#  ('CCDC152', 2),
#  ('SYCP1', 2),
#  ('SLC9A3R2', 2),
#  ('LOC100272146', 2),
#  ('HS3ST4', 2),
#  ('CRB3', 2),
#  ('CASZ1', 2),
#  ('ANKFY1', 2),
#  ('USP2', 2),
#  ('SYNJ2', 2),
#  ('MMP14', 2),
#  ('BAI1', 2),
#  ('IRF6', 2),
#  ('PPIE', 2),
#  ('N4BP3', 2),
#  ('HOXA5', 2),
#  ('FAM83H', 2),
#  ('FBLN2', 2),
#  ('MYO1C', 2),
#  ('NUP210', 2),
#  ('NR2F1', 2),
#  ('CSNK1G2', 2),
#  ('L1TD1', 2),
#  ('TPM3', 2),
#  ('FRMD4A', 2),
#  ('HSD17B8', 2),
#  ('ABCG4', 2),
#  ('FAT3', 2),
#  ('COPG', 2),
#  ('RASL11B', 2),
#  ('ELAVL3', 2),
#  ('C12orf72', 2),
#  ('RUFY1', 2),
#  ('LIMD1', 2),
#  ('NOS3', 2),
#  ('EPN2', 2),
#  ('SCOC', 2),
#  ('ATF6B', 2),
#  ('NRG2', 2),
#  ('WWTR1', 2),
#  ('SHC1', 2),
#  ('TRIO', 2),
#  ('NR4A3', 2),
#  ('CNPY1', 2),
#  ('DEF8', 2),
#  ('NPTX2', 2),
#  ('CYB561D1', 2),
#  ('TEAD1', 2),
#  ('BUB3', 2),
#  ('EDNRB', 2),
#  ('DOC2B', 2),
#  ('SLC22A15', 2),
#  ('MEIS1', 2),
#  ('TERT', 2),
#  ('RCAN1', 2),
#  ('PRICKLE1', 2),
#  ('LIMCH1', 2),
#  ('RDBP', 2),
#  ('SGPP2', 2),
#  ('RASSF5', 2),
#  ('LHFPL3', 2),
#  ('GFOD1', 2),
#  ('VAC14', 2),
#  ('ELN', 2),
#  ('TTC7A', 2),
#  ('DPF1', 2),
#  ('ANKRD28', 2),
#  ('ESRP2', 2),
#  ('C13orf36', 2),
#  ('C2CD2L', 2),
#  ('RNPEP', 2),
#  ('TMTC1', 2),
#  ('MBNL1', 2),
#  ('GPX5', 2),
#  ('UGT3A1', 2),
#  ('FAM65C', 2),
#  ('FGGY', 2),
#  ('SIRPA', 2),
#  ('BHLHE40', 2),
#  ('DIRC3', 2),
#  ('LPP', 2),
#  ('UNC5A', 2),
#  ('MYOM2', 2),
#  ('PPP1R10', 2),
#  ('FAM91A1', 2),
#  ('FLJ90757', 2),
#  ('DAB2IP', 2),
#  ('CDH13', 2),
#  ('CMIP', 2),
#  ('CDH8', 2),
#  ('HOXB3', 2),
#  ('GJB3', 2),
#  ('ZNF709', 2),
#  ('BARD1', 2),
#  ('INPP5D', 2),
#  ('MMEL1', 2),
#  ('TMEM49', 2),
#  ('CACNA1I', 2),
#  ('HDAC9', 2),
#  ('ST3GAL2', 2),
#  ('SLIT3', 2),
#  ('ARID5B', 2),
#  ('PYCARD', 2),
#  ('KRT19', 2),
#  ('FAM38A', 2),
#  ('BCAS3', 2),
#  ('MTUS2', 2),
#  ('JAG2', 2),
#  ('SETD8', 2),
#  ('KCNK5', 2),
#  ('LRRC17', 2),
#  ('C13orf26', 2),
#  ('TNS1', 2),
#  ('RBP1', 2),
#  ('C22orf27', 2),
#  ('HLA-J', 2),
#  ('SCRIB', 2),
#  ('PTH1R', 2),
#  ('ZNF718', 2),
#  ('SCNN1D', 2),
#  ('PRDM1', 2),
#  ('KCTD14', 2),
#  ('SH3PXD2A', 2),
#  ('KLC1', 2),
#  ('RBM47', 2),
#  ('C6orf25', 2),
#  ('SLC12A4', 2),
#  ('OTOP3', 2),
#  ('BTNL9', 2),
#  ('UPF2', 2),
#  ('TCEA2', 2),
#  ('UBASH3A', 2),
#  ('SLC25A25', 2),
#  ('IGSF11', 2),
#  ('LTC4S', 2),
#  ('TECR', 2),
#  ('CWH43', 2),
#  ('NCRNA00111', 2),
#  ('MAP4K2', 2),
#  ('ODZ2', 2),
#  ('KCNJ9', 2),
#  ('LOC646214', 2),
#  ('TMC5', 2),
#  ('SLITRK1', 2),
#  ('C1orf70', 2),
#  ('DLEU2', 2),
#  ('SLC12A7', 2),
#  ('MYOF', 2),
#  ('KCNQ2', 2),
#  ('C8orf80', 2),
#  ('TMEM176B', 2),
#  ('DUSP16', 2),
#  ('EBF2', 2),
#  ('FANCI', 2),
#  ('SULT1A1', 2),
#  ('BGLAP', 2),
#  ('SHISA6', 2),
#  ('CPLX1', 2),
#  ('POMC', 2),
#  ('RCCD1', 2),
#  ('TOX', 2),
#  ('TNRC6C', 2),
#  ('TBX5', 2),
#  ('SMTNL2', 2),
#  ('NPC1', 2),
#  ('HSPA1L', 2),
#  ('FBXO47', 2),
#  ('TNRC4', 2),
#  ('KIAA1239', 2),
#  ('ELL2', 2),
#  ('TUBB', 2),
#  ('RIN3', 2),
#  ('PPFIA3', 2),
#  ('FLRT2', 2),
#  ('SLC17A9', 2),
#  ('DIO3', 2),
#  ('HOXA1', 2),
#  ('TMEM63A', 2),
#  ('DUSP22', 2),
#  ('PPP1R1B', 2),
#  ('RAD21', 2),
#  ('GATA6', 2),
#  ('PTPN20B', 2),
#  ('MYO16', 2),
#  ('AMBRA1', 2),
#  ('NXPH2', 2),
#  ('PLIN5', 2),
#  ('HLA-F', 2),
#  ('ATP2B2', 2),
#  ('IL17REL', 2),
#  ('IGDCC3', 2),
#  ('FGFR2', 2),
#  ('ABR', 2),
#  ('CCDC88B', 2),
#  ('MBP', 2),
#  ('CLIC1', 2),
#  ('C3orf26', 2),
#  ('CBLC', 2),
#  ('GAB4', 2),
#  ('SLC1A2', 2),
#  ('THEMIS', 2),
#  ('PLEKHA6', 2),
#  ('ASAM', 2),
#  ('SPOCK1', 2),
#  ('ZMYND15', 2),
#  ('TBPL2', 2),
#  ('FAM110A', 2),
#  ('ProSAPiP1', 2),
#  ('AFAP1', 2),
#  ('PLXNA1', 2),
#  ('MAN2B1', 2),
#  ('PRR5L', 2),
#  ('TBC1D16', 2),
#  ('NALCN', 2),
#  ('TACR3', 2),
#  ('ARHGAP23', 2),
#  ('DHRS3', 2),
#  ('PTPRS', 2),
#  ('VTRNA1-2', 2),
#  ('UBR4', 2),
#  ('SPNS2', 2),
#  ('AJAP1', 2),
#  ('MYLK4', 2),
#  ('RGL1', 2),
#  ('RGS14', 2),
#  ('TEX2', 2),
#  ('NTN3', 2),
#  ('SLITRK3', 2),
#  ('RNF215', 2),
#  ('CRYGD', 2),
#  ('FGF12', 2),
#  ('EPHA2', 2),
#  ('MMP19', 2),
#  ('C14orf143', 2),
#  ('C2orf58', 2),
#  ('ALPI', 2),
#  ('DUSP3', 2),
#  ('IL9', 2),
#  ('SH2B2', 2),
#  ('MPHOSPH9', 2),
#  ('APITD1', 2),
#  ('ROBO1', 2),
#  ('ASPDH', 2),
#  ('CCDC52', 2),
#  ('LGMN', 2),
#  ('SHOX2', 2),
#  ('TNFRSF1B', 2),
#  ('KCNH2', 2),
#  ('CNST', 2),
#  ('C17orf55', 2),
#  ('GPR124', 2),
#  ('DDAH1', 2),
#  ('COL9A2', 2),
#  ('PPP2R2B', 2),
#  ('PHYHIP', 2),
#  ('NTM', 2),
#  ('NEURL', 2),
#  ('KIAA1598', 2),
#  ('PRR5', 2),
#  ('NDRG1', 2),
#  ('CBLN4', 2),
#  ('TXNRD1', 2),
#  ('OTUD7A', 2),
#  ('MYADM', 2),
#  ('ESYT3', 2),
#  ('FLJ40330', 2),
#  ('PSMB8', 2),
#  ('VENTX', 2),
#  ('C5orf43', 2),
#  ('PHLDB1', 2),
#  ('C9orf86', 2),
#  ('DENND2D', 2),
#  ('DOK4', 2),
#  ('SPTBN5', 2),
#  ('DPYS', 2),
#  ('GPR78', 2),
#  ('IGLON5', 2),
#  ('PCDH15', 2),
#  ('SOX1', 2),
#  ('TNNT1', 2),
#  ('RYR2', 2),
#  ('FBXL18', 2),
#  ('MEFV', 2),
#  ('TMEM175', 2),
#  ('RAB37', 2),
#  ('STK39', 2),
#  ('LMX1B', 2),
#  ('OSBPL3', 2),
#  ('C9orf3', 2),
#  ('PLBD1', 2),
#  ('B3GNT7', 2),
#  ('PENK', 2),
#  ('IQCE', 2),
#  ('BAHD1', 2),
#  ('FOXD2', 2),
#  ('GPD1', 2),
#  ('GNAT1', 2),
#  ('PARVA', 2),
#  ('ATP8B4', 2),
#  ('C19orf45', 2),
#  ('RAB7A', 2),
#  ('SLAMF1', 2),
#  ('IRX5', 2),
#  ('BOP1', 2),
#  ('REC8', 2),
#  ('RARRES2', 2),
#  ('ALX4', 2),
#  ('PCDHB3', 2),
#  ('RGR', 2),
#  ...]

# %%
# for gene in importantGenesUniqueList:
#     if "CDK" in gene:
#         print(gene)
import math
relatedCpgs = set()
for cpg in list(importantCpgs.dropna(subset=['UCSC_RefGene_Name']).index):
    genes = importantCpgs.loc[cpg,'UCSC_RefGene_Name'].split(";")
    for gene in genes:
        if gene == "RPTOR":
            relatedCpgs.add(importantCpgs.loc[cpg,'IlmnID'])
            
print(list(relatedCpgs))
# Out:
# cg01498832
# cg01498832
# cg03502601
# cg03502601
# cg04662369
# cg04662369
# cg06418238
# cg06418238
# cg06872548
# cg06872548
# cg07126783
# cg07126783
# cg07786220
# cg07786220
# cg08939850
# cg08939850
# cg09929238
# cg09929238
# cg11949518
# cg11949518
# cg12078154
# cg12078154
# cg16115689
# cg16115689
# cg16638092
# cg16638092
# cg22091236
# cg22091236
# cg22386583
# cg22386583
# cg25902229
# cg25902229
